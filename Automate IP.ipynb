# %%
from PIL import Image
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\SAMPLE'

# %%
# Let us import one image in our Jupyter environment and open that in the notebook itself

image1 = Image.open("snow.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1075x555 at 0x206771731F0>

# %%
image1.show()

# %%
image1.save("pic1.png")

# %%
# lists all the files and folders in the current working directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abd.png',
#  'Automate IP.ipynb',
#  'Bitwise.ipynb',
#  'blurred.png',
#  'burred.png',
#  'Canvas.ipynb',
#  'canvas3.png',
#  'canvas4.jpg',
#  'cat_damaged.png',
#  'cat_inpainted.png',
#  'cat_mask.png',
#  'collage.png',
#  'Countour.ipynb',
#  'countour.png',
#  'crop.png',
#  'dice.png',
#  'Diff btwn Images.ipynb',
#  'diff1.jpg',
#  'diff2.jpg',
#  'f.jpg',
#  'face.jpg',
#  'face1.png',
#  'face2.png',
#  'Filtering an image.ipynb',
#  'fruit.jpg',
#  'gfg_dummy_pic.png',
#  'gontu.jpg',
#  'grey_scale.ipynb',
#  'im1.png',
#  'im10.png',
#  'im11.jpg',
#  'im2.png',
#  'im3.png',
#  'im4.png',
#  'im5.png',
#  'im6.png',
#  'im7.png',
#  'im8.png',
#  'im9.png',
#  'Image Manipulation.ipynb',
#  'image3.jpg',
#  'Image_from_array.png',
#  'img6.jpg',
#  'Intensive Transformation.ipynb',
#  'Interpolation.ipynb',
#  'Inverting From One Folder To Another.ipynb',
#  'Listing Images.ipynb',
#  'logo.png',
#  'logo1.png',
#  'logo6.png',
#  'Matrix To Image.ipynb',
#  'mintu.jpg',
#  'Montage.ipynb',
#  'montage.png',
#  'nature.jpg',
#  'new.png',
#  'nike.png',
#  'Noise.ipynb',
#  'noisy.jpg',
#  'pic1.png',
#  'read,write and display.ipynb',
#  'Remove BG.ipynb',
#  'Restoration1.ipynb',
#  'Restore Image.ipynb',
#  'restore.png',
#  's.png',
#  's1.png',
#  'Sampling.ipynb',
#  'snow.jpg',
#  'square.png',
#  'square1.png',
#  'statistics.ipynb',
#  'Text Removal.ipynb',
#  'text_removed_image.jpg',
#  'text_removed_image1.jpg',
#  'watermark.png',
#  'watermark1.png',
#  'watermark2.png']

# %%
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# abd & .png
# blurred & .png
# burred & .png
# canvas3 & .png
# cat_damaged & .png
# cat_inpainted & .png
# cat_mask & .png
# collage & .png
# countour & .png
# crop & .png
# dice & .png
# face1 & .png
# face2 & .png
# gfg_dummy_pic & .png
# im1 & .png
# im10 & .png
# im2 & .png
# im3 & .png
# im4 & .png
# im5 & .png
# im6 & .png
# im7 & .png
# im8 & .png
# im9 & .png
# Image_from_array & .png
# logo & .png
# logo1 & .png
# logo6 & .png
# montage & .png
# new & .png
# nike & .png
# pic1 & .png
# restore & .png
# s & .png
# s1 & .png
# square & .png
# square1 & .png
# watermark & .png
# watermark1 & .png
# watermark2 & .png

# %%
#Looping over the image files
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# canvas4.jpg
# diff1.jpg
# diff2.jpg
# f.jpg
# face.jpg
# fruit.jpg
# gontu.jpg
# im11.jpg
# image3.jpg
# img6.jpg
# mintu.jpg
# nature.jpg
# noisy.jpg
# snow.jpg
# text_removed_image.jpg
# text_removed_image1.jpg

# %%
# Creating new Directory using OS library
os.mkdir('BewExtnsn')
# Note: If you already have a directory with this name, you will get error.

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("BewExtnsn/{}.pdf".format(fn))

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')
# Note: If you already have a directory with this name, you will get error.

# %%
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))

# %%
image2 = Image.open("im6.png")
image2 = image2.convert(mode='L')
image2
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x20677352940>

# %%
# Creating new Directory using OS library
os.mkdir('b&w')

# %%
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.convert(mode = 'L')
        im.save("b&w/{}_bw.{}".format(fn, fext))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\PIL\Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
#rotating the image to 55 Degree angle
image3 = Image.open("im7.png")
image3.rotate(55).save("image3.jpg")
Image3 = Image.open("image3.jpg")
Image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x360 at 0x20677421B20>

# %%
# Creating new Directory using OS library
os.mkdir('rotate')

# %%
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
